# %%
import pandas as pd
import keras
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input, Embedding, BatchNormalization, concatenate
from keras.optimizers import Adam
from keras.layers.merge import dot
from keras.models import Model
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rating_data = pd.read_csv('final_data.csv')

# %%
rating_data
# Out:
#      Unnamed: 0  user_id  battery_id  rating  Energy_conumption_perday  \
# 0             0      106           1       5                  0.141978
# 1             1       36           1       5                  0.106142
# 2             2       63           1       1                  0.020238
# 3             3      103           1       5                  0.115439
# 4             4        8           1       4                  0.603963
# ..          ...      ...         ...     ...                       ...
# 603         603      134          34       2                  0.414123
# 604         604      136          34       4                  0.410597
# 605         605      104          34       3                  0.043210
# 606         606       24          34       3                  0.357814
# 607         607       45          34       3                  0.945032
#
#      battery_brand  volume(kwh)     Price
# 0                1     0.620112  0.265931
# 1                1     0.620112  0.265931
# 2                1     0.620112  0.265931
# 3                1     0.620112  0.265931
# 4                1     0.620112  0.265931
# ..             ...          ...       ...
# 603             34     0.329609  0.129902
# 604             34     0.329609  0.129902
# 605             34     0.329609  0.129902
# 606             34     0.329609  0.129902
# 607             34     0.329609  0.129902
#
# [608 rows x 8 columns]

# %%
rating_data['side_info_user'] = rating_data['Energy_conumption_perday']

# %%
rating_data['side_info_item'] = rating_data['volume(kwh)']+rating_data['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(rating_data[['user_id','battery_id','side_info_user','side_info_item']], rating_data[['rating']], test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      user_id  battery_id  side_info_user  side_info_item
# 436       59          31        0.136904        0.279480
# 131       72          23        0.418084        1.017171
# 490       40          25        0.609862        0.537915
# 148       39          15        0.015103        0.238642
# 9        107           1        0.039148        0.886043
# ..       ...         ...             ...             ...
# 71        79          10        0.125695        0.355889
# 106      129          22        0.027068        1.274510
# 270       37          20        0.392672        0.706837
# 435       85          31        0.035515        0.279480
# 102       12          13        0.145216        0.079657
#
# [486 rows x 4 columns]

# %%
num_users = 150
num_batteries = 39

# %%
aux_input_user = Input(shape=(1,))
aux_dense1 = Dense(128, activation='relu')(aux_input_user)
aux_dense1 = Dropout(0.2)(aux_dense1)
aux_dense_user = Dense(64, activation='relu')(aux_dense1)
aux_dense_user.shape
# Out:
# TensorShape([None, 64])

# %%
aux_input_item = Input(shape=(1,))
aux_dense1 = Dense(128, activation='relu')(aux_input_item)
aux_dense1 = Dropout(0.2)(aux_dense1)
aux_dense_item = Dense(64, activation='relu')(aux_dense1)
aux_dense_item.shape
# Out:
# TensorShape([None, 64])

# %%
latent_factors = 10

# %%
user_input = Input(shape=(1,),name='user_input', dtype='int32')
user_embedding = Embedding(num_users+1, latent_factors, name='user_embedding')(user_input)
user_flat = Flatten(name='user_flat')(user_embedding)
user_flat = Dropout(0.2)(user_flat)
user_dense = Dense(256, activation='relu')(user_flat)
user_dense = Dropout(0.2)(user_dense)
user_dense = Dense(128, activation='relu')(user_dense)
user_dense = Dropout(0.2)(user_dense)
user_dense = Dense(64, activation='relu')(user_dense)

# %%
user_dense.shape
# Out:
# TensorShape([None, 64])

# %%
concat_user = concatenate([user_dense,aux_dense_user],axis=-1)

# %%
concat_user.shape
# Out:
# TensorShape([None, 128])

# %%
battery_input = Input(shape=(1,),name='battery_input', dtype='int32')
battery_embedding = Embedding(num_batteries+1, latent_factors, name='battery_embedding')(battery_input)
battery_flat = Flatten(name='battery_flat')(battery_embedding)
battery_flat = Dropout(0.2)(battery_flat)
battery_dense = Dense(256, activation='relu')(battery_flat)
battery_dense = Dropout(0.2)(battery_dense)
battery_dense = Dense(128, activation='relu')(battery_dense)
battery_dense = Dropout(0.2)(user_dense)
battery_dense = Dense(64, activation='relu')(battery_dense)

# %%
concat_battery = concatenate([battery_dense,aux_dense_item],axis=-1)

# %%
product=dot([concat_user, concat_battery], name='product', axes=1)

# %%
dense1 = Dense(512, activation='relu')(product)
dense1 = Dropout(0.2)(dense1)
dense2 = Dense(256, activation='relu')(dense1)
dense2 = Dropout(0.2)(dense2)
dense3 = Dense(128, activation='relu')(dense2)
dense3 = Dropout(0.2)(dense3)
dense4 = Dense(64, activation='relu')(dense3)
dense_out = Dense(1, activation='relu')(dense4)

# %%
model = Model([user_input,aux_input_user,battery_input,aux_input_item],dense_out)

# %%
learning_rate = 1e-4
epochs = 120
batch_size = 256

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        min_delta=1e-3,
        patience=4,
        verbose=1)
]

# %%
model.compile(optimizer=Adam(lr=learning_rate), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

# %%
history = model.fit([x_train['user_id'], x_train['side_info_user'],x_train['battery_id'],x_train['side_info_item']], y_train,
                batch_size=batch_size,
                epochs=epochs,
                shuffle=True, 
                validation_split=0.25)
# Out:
# Train on 364 samples, validate on 122 samples
# Epoch 1/120
# 364/364 [==============================] - 0s 52us/step - loss: 2.0550 - root_mean_squared_error: 2.7559 - mean_absolute_error: 2.3662 - val_loss: 2.4612 - val_root_mean_squared_error: 2.7490 - val_mean_absolute_error: 2.3581
# Epoch 2/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.9641 - root_mean_squared_error: 2.7362 - mean_absolute_error: 2.3427 - val_loss: 2.4495 - val_root_mean_squared_error: 2.7294 - val_mean_absolute_error: 2.3349
# Epoch 3/120
# 364/364 [==============================] - 0s 52us/step - loss: 2.0216 - root_mean_squared_error: 2.7171 - mean_absolute_error: 2.3203 - val_loss: 2.4161 - val_root_mean_squared_error: 2.7105 - val_mean_absolute_error: 2.3129
# Epoch 4/120
# 364/364 [==============================] - 0s 49us/step - loss: 2.0856 - root_mean_squared_error: 2.6987 - mean_absolute_error: 2.2989 - val_loss: 2.3677 - val_root_mean_squared_error: 2.6924 - val_mean_absolute_error: 2.2918
# Epoch 5/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8997 - root_mean_squared_error: 2.6805 - mean_absolute_error: 2.2781 - val_loss: 2.3160 - val_root_mean_squared_error: 2.6743 - val_mean_absolute_error: 2.2711
# Epoch 6/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8643 - root_mean_squared_error: 2.6629 - mean_absolute_error: 2.2579 - val_loss: 2.2719 - val_root_mean_squared_error: 2.6566 - val_mean_absolute_error: 2.2510
# Epoch 7/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.9661 - root_mean_squared_error: 2.6457 - mean_absolute_error: 2.2385 - val_loss: 2.2391 - val_root_mean_squared_error: 2.6397 - val_mean_absolute_error: 2.2317
# Epoch 8/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.9192 - root_mean_squared_error: 2.6288 - mean_absolute_error: 2.2193 - val_loss: 2.2169 - val_root_mean_squared_error: 2.6231 - val_mean_absolute_error: 2.2130
# Epoch 9/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.8468 - root_mean_squared_error: 2.6125 - mean_absolute_error: 2.2010 - val_loss: 2.2029 - val_root_mean_squared_error: 2.6068 - val_mean_absolute_error: 2.1948
# Epoch 10/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.9926 - root_mean_squared_error: 2.5968 - mean_absolute_error: 2.1836 - val_loss: 2.1945 - val_root_mean_squared_error: 2.5913 - val_mean_absolute_error: 2.1777
# Epoch 11/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.9624 - root_mean_squared_error: 2.5815 - mean_absolute_error: 2.1667 - val_loss: 2.1940 - val_root_mean_squared_error: 2.5762 - val_mean_absolute_error: 2.1610
# Epoch 12/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.8607 - root_mean_squared_error: 2.5664 - mean_absolute_error: 2.1501 - val_loss: 2.1980 - val_root_mean_squared_error: 2.5612 - val_mean_absolute_error: 2.1445
# Epoch 13/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.7862 - root_mean_squared_error: 2.5515 - mean_absolute_error: 2.1338 - val_loss: 2.2080 - val_root_mean_squared_error: 2.5465 - val_mean_absolute_error: 2.1284
# Epoch 14/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.9295 - root_mean_squared_error: 2.5373 - mean_absolute_error: 2.1183 - val_loss: 2.2234 - val_root_mean_squared_error: 2.5325 - val_mean_absolute_error: 2.1131
# Epoch 15/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.7786 - root_mean_squared_error: 2.5232 - mean_absolute_error: 2.1029 - val_loss: 2.2372 - val_root_mean_squared_error: 2.5185 - val_mean_absolute_error: 2.0980
# Epoch 16/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8965 - root_mean_squared_error: 2.5097 - mean_absolute_error: 2.0882 - val_loss: 2.2508 - val_root_mean_squared_error: 2.5051 - val_mean_absolute_error: 2.0835
# Epoch 17/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.9267 - root_mean_squared_error: 2.4967 - mean_absolute_error: 2.0742 - val_loss: 2.2570 - val_root_mean_squared_error: 2.4922 - val_mean_absolute_error: 2.0695
# Epoch 18/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8619 - root_mean_squared_error: 2.4838 - mean_absolute_error: 2.0602 - val_loss: 2.2547 - val_root_mean_squared_error: 2.4794 - val_mean_absolute_error: 2.0558
# Epoch 19/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8314 - root_mean_squared_error: 2.4712 - mean_absolute_error: 2.0469 - val_loss: 2.2493 - val_root_mean_squared_error: 2.4669 - val_mean_absolute_error: 2.0425
# Epoch 20/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.8105 - root_mean_squared_error: 2.4589 - mean_absolute_error: 2.0339 - val_loss: 2.2401 - val_root_mean_squared_error: 2.4546 - val_mean_absolute_error: 2.0296
# Epoch 21/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7962 - root_mean_squared_error: 2.4468 - mean_absolute_error: 2.0212 - val_loss: 2.2328 - val_root_mean_squared_error: 2.4426 - val_mean_absolute_error: 2.0169
# Epoch 22/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8153 - root_mean_squared_error: 2.4349 - mean_absolute_error: 2.0086 - val_loss: 2.2334 - val_root_mean_squared_error: 2.4309 - val_mean_absolute_error: 2.0046
# Epoch 23/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.8828 - root_mean_squared_error: 2.4236 - mean_absolute_error: 1.9967 - val_loss: 2.2335 - val_root_mean_squared_error: 2.4197 - val_mean_absolute_error: 1.9929
# Epoch 24/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.7371 - root_mean_squared_error: 2.4122 - mean_absolute_error: 1.9848 - val_loss: 2.2358 - val_root_mean_squared_error: 2.4083 - val_mean_absolute_error: 1.9809
# Epoch 25/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.7443 - root_mean_squared_error: 2.4011 - mean_absolute_error: 1.9732 - val_loss: 2.2313 - val_root_mean_squared_error: 2.3973 - val_mean_absolute_error: 1.9694
# Epoch 26/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.7929 - root_mean_squared_error: 2.3902 - mean_absolute_error: 1.9621 - val_loss: 2.2269 - val_root_mean_squared_error: 2.3866 - val_mean_absolute_error: 1.9585
# Epoch 27/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7987 - root_mean_squared_error: 2.3797 - mean_absolute_error: 1.9513 - val_loss: 2.2209 - val_root_mean_squared_error: 2.3761 - val_mean_absolute_error: 1.9477
# Epoch 28/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7146 - root_mean_squared_error: 2.3691 - mean_absolute_error: 1.9404 - val_loss: 2.2151 - val_root_mean_squared_error: 2.3657 - val_mean_absolute_error: 1.9370
# Epoch 29/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6998 - root_mean_squared_error: 2.3589 - mean_absolute_error: 1.9300 - val_loss: 2.2016 - val_root_mean_squared_error: 2.3554 - val_mean_absolute_error: 1.9267
# Epoch 30/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6601 - root_mean_squared_error: 2.3488 - mean_absolute_error: 1.9197 - val_loss: 2.1935 - val_root_mean_squared_error: 2.3453 - val_mean_absolute_error: 1.9163
# Epoch 31/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7435 - root_mean_squared_error: 2.3390 - mean_absolute_error: 1.9098 - val_loss: 2.1908 - val_root_mean_squared_error: 2.3356 - val_mean_absolute_error: 1.9065
# Epoch 32/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6615 - root_mean_squared_error: 2.3292 - mean_absolute_error: 1.8996 - val_loss: 2.1994 - val_root_mean_squared_error: 2.3259 - val_mean_absolute_error: 1.8964
# Epoch 33/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6780 - root_mean_squared_error: 2.3196 - mean_absolute_error: 1.8899 - val_loss: 2.2131 - val_root_mean_squared_error: 2.3164 - val_mean_absolute_error: 1.8868
# Epoch 34/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6623 - root_mean_squared_error: 2.3102 - mean_absolute_error: 1.8804 - val_loss: 2.2242 - val_root_mean_squared_error: 2.3072 - val_mean_absolute_error: 1.8775
# Epoch 35/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.7297 - root_mean_squared_error: 2.3012 - mean_absolute_error: 1.8715 - val_loss: 2.2304 - val_root_mean_squared_error: 2.2982 - val_mean_absolute_error: 1.8686
# Epoch 36/120
# 364/364 [==============================] - 0s 55us/step - loss: 1.5908 - root_mean_squared_error: 2.2921 - mean_absolute_error: 1.8624 - val_loss: 2.2242 - val_root_mean_squared_error: 2.2891 - val_mean_absolute_error: 1.8596
# Epoch 37/120
# 364/364 [==============================] - 0s 55us/step - loss: 1.6982 - root_mean_squared_error: 2.2833 - mean_absolute_error: 1.8537 - val_loss: 2.2172 - val_root_mean_squared_error: 2.2805 - val_mean_absolute_error: 1.8510
# Epoch 38/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5612 - root_mean_squared_error: 2.2745 - mean_absolute_error: 1.8447 - val_loss: 2.2137 - val_root_mean_squared_error: 2.2717 - val_mean_absolute_error: 1.8420
# Epoch 39/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7392 - root_mean_squared_error: 2.2662 - mean_absolute_error: 1.8366 - val_loss: 2.2140 - val_root_mean_squared_error: 2.2634 - val_mean_absolute_error: 1.8339
# Epoch 40/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5526 - root_mean_squared_error: 2.2577 - mean_absolute_error: 1.8280 - val_loss: 2.2206 - val_root_mean_squared_error: 2.2549 - val_mean_absolute_error: 1.8255
# Epoch 41/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.7284 - root_mean_squared_error: 2.2496 - mean_absolute_error: 1.8203 - val_loss: 2.2312 - val_root_mean_squared_error: 2.2470 - val_mean_absolute_error: 1.8179
# Epoch 42/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.6302 - root_mean_squared_error: 2.2415 - mean_absolute_error: 1.8124 - val_loss: 2.2424 - val_root_mean_squared_error: 2.2390 - val_mean_absolute_error: 1.8100
# Epoch 43/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5712 - root_mean_squared_error: 2.2336 - mean_absolute_error: 1.8046 - val_loss: 2.2571 - val_root_mean_squared_error: 2.2310 - val_mean_absolute_error: 1.8022
# Epoch 44/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.6532 - root_mean_squared_error: 2.2259 - mean_absolute_error: 1.7972 - val_loss: 2.2725 - val_root_mean_squared_error: 2.2234 - val_mean_absolute_error: 1.7949
# Epoch 45/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.7431 - root_mean_squared_error: 2.2183 - mean_absolute_error: 1.7900 - val_loss: 2.2841 - val_root_mean_squared_error: 2.2160 - val_mean_absolute_error: 1.7880
# Epoch 46/120
# 364/364 [==============================] - 0s 63us/step - loss: 1.6211 - root_mean_squared_error: 2.2111 - mean_absolute_error: 1.7832 - val_loss: 2.2855 - val_root_mean_squared_error: 2.2086 - val_mean_absolute_error: 1.7808
# Epoch 47/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6310 - root_mean_squared_error: 2.2037 - mean_absolute_error: 1.7759 - val_loss: 2.2811 - val_root_mean_squared_error: 2.2013 - val_mean_absolute_error: 1.7738
# Epoch 48/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.6367 - root_mean_squared_error: 2.1964 - mean_absolute_error: 1.7691 - val_loss: 2.2647 - val_root_mean_squared_error: 2.1942 - val_mean_absolute_error: 1.7671
# Epoch 49/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.4970 - root_mean_squared_error: 2.1892 - mean_absolute_error: 1.7620 - val_loss: 2.2519 - val_root_mean_squared_error: 2.1869 - val_mean_absolute_error: 1.7600
# Epoch 50/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.6519 - root_mean_squared_error: 2.1822 - mean_absolute_error: 1.7555 - val_loss: 2.2414 - val_root_mean_squared_error: 2.1800 - val_mean_absolute_error: 1.7535
# Epoch 51/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5357 - root_mean_squared_error: 2.1752 - mean_absolute_error: 1.7487 - val_loss: 2.2393 - val_root_mean_squared_error: 2.1730 - val_mean_absolute_error: 1.7467
# Epoch 52/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5773 - root_mean_squared_error: 2.1684 - mean_absolute_error: 1.7422 - val_loss: 2.2429 - val_root_mean_squared_error: 2.1662 - val_mean_absolute_error: 1.7403
# Epoch 53/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.6839 - root_mean_squared_error: 2.1619 - mean_absolute_error: 1.7361 - val_loss: 2.2522 - val_root_mean_squared_error: 2.1597 - val_mean_absolute_error: 1.7341
# Epoch 54/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5601 - root_mean_squared_error: 2.1552 - mean_absolute_error: 1.7299 - val_loss: 2.2629 - val_root_mean_squared_error: 2.1531 - val_mean_absolute_error: 1.7281
# Epoch 55/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.6472 - root_mean_squared_error: 2.1488 - mean_absolute_error: 1.7239 - val_loss: 2.2778 - val_root_mean_squared_error: 2.1468 - val_mean_absolute_error: 1.7221
# Epoch 56/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.6349 - root_mean_squared_error: 2.1425 - mean_absolute_error: 1.7180 - val_loss: 2.2927 - val_root_mean_squared_error: 2.1405 - val_mean_absolute_error: 1.7163
# Epoch 57/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5371 - root_mean_squared_error: 2.1363 - mean_absolute_error: 1.7122 - val_loss: 2.3032 - val_root_mean_squared_error: 2.1342 - val_mean_absolute_error: 1.7104
# Epoch 58/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4834 - root_mean_squared_error: 2.1299 - mean_absolute_error: 1.7061 - val_loss: 2.3041 - val_root_mean_squared_error: 2.1280 - val_mean_absolute_error: 1.7045
# Epoch 59/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5501 - root_mean_squared_error: 2.1238 - mean_absolute_error: 1.7005 - val_loss: 2.2953 - val_root_mean_squared_error: 2.1219 - val_mean_absolute_error: 1.6988
# Epoch 60/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5994 - root_mean_squared_error: 2.1179 - mean_absolute_error: 1.6949 - val_loss: 2.2854 - val_root_mean_squared_error: 2.1160 - val_mean_absolute_error: 1.6934
# Epoch 61/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5806 - root_mean_squared_error: 2.1120 - mean_absolute_error: 1.6896 - val_loss: 2.2742 - val_root_mean_squared_error: 2.1101 - val_mean_absolute_error: 1.6880
# Epoch 62/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.4513 - root_mean_squared_error: 2.1060 - mean_absolute_error: 1.6838 - val_loss: 2.2639 - val_root_mean_squared_error: 2.1041 - val_mean_absolute_error: 1.6822
# Epoch 63/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4667 - root_mean_squared_error: 2.1001 - mean_absolute_error: 1.6784 - val_loss: 2.2572 - val_root_mean_squared_error: 2.0983 - val_mean_absolute_error: 1.6767
# Epoch 64/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.5030 - root_mean_squared_error: 2.0943 - mean_absolute_error: 1.6728 - val_loss: 2.2514 - val_root_mean_squared_error: 2.0925 - val_mean_absolute_error: 1.6713
# Epoch 65/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5580 - root_mean_squared_error: 2.0888 - mean_absolute_error: 1.6678 - val_loss: 2.2490 - val_root_mean_squared_error: 2.0870 - val_mean_absolute_error: 1.6663
# Epoch 66/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4861 - root_mean_squared_error: 2.0831 - mean_absolute_error: 1.6626 - val_loss: 2.2589 - val_root_mean_squared_error: 2.0814 - val_mean_absolute_error: 1.6612
# Epoch 67/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4526 - root_mean_squared_error: 2.0776 - mean_absolute_error: 1.6575 - val_loss: 2.2690 - val_root_mean_squared_error: 2.0759 - val_mean_absolute_error: 1.6560
# Epoch 68/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4952 - root_mean_squared_error: 2.0722 - mean_absolute_error: 1.6525 - val_loss: 2.2708 - val_root_mean_squared_error: 2.0705 - val_mean_absolute_error: 1.6511
# Epoch 69/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4842 - root_mean_squared_error: 2.0668 - mean_absolute_error: 1.6477 - val_loss: 2.2732 - val_root_mean_squared_error: 2.0651 - val_mean_absolute_error: 1.6462
# Epoch 70/120
# 364/364 [==============================] - 0s 44us/step - loss: 1.5644 - root_mean_squared_error: 2.0616 - mean_absolute_error: 1.6429 - val_loss: 2.2825 - val_root_mean_squared_error: 2.0600 - val_mean_absolute_error: 1.6416
# Epoch 71/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5536 - root_mean_squared_error: 2.0565 - mean_absolute_error: 1.6383 - val_loss: 2.3037 - val_root_mean_squared_error: 2.0549 - val_mean_absolute_error: 1.6370
# Epoch 72/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.5322 - root_mean_squared_error: 2.0515 - mean_absolute_error: 1.6336 - val_loss: 2.3290 - val_root_mean_squared_error: 2.0499 - val_mean_absolute_error: 1.6323
# Epoch 73/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4919 - root_mean_squared_error: 2.0465 - mean_absolute_error: 1.6291 - val_loss: 2.3507 - val_root_mean_squared_error: 2.0449 - val_mean_absolute_error: 1.6278
# Epoch 74/120
# 364/364 [==============================] - 0s 44us/step - loss: 1.4377 - root_mean_squared_error: 2.0414 - mean_absolute_error: 1.6244 - val_loss: 2.3622 - val_root_mean_squared_error: 2.0399 - val_mean_absolute_error: 1.6232
# Epoch 75/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4516 - root_mean_squared_error: 2.0365 - mean_absolute_error: 1.6200 - val_loss: 2.3546 - val_root_mean_squared_error: 2.0350 - val_mean_absolute_error: 1.6188
# Epoch 76/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.4538 - root_mean_squared_error: 2.0316 - mean_absolute_error: 1.6156 - val_loss: 2.3380 - val_root_mean_squared_error: 2.0301 - val_mean_absolute_error: 1.6144
# Epoch 77/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.4320 - root_mean_squared_error: 2.0268 - mean_absolute_error: 1.6112 - val_loss: 2.3148 - val_root_mean_squared_error: 2.0253 - val_mean_absolute_error: 1.6100
# Epoch 78/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.4378 - root_mean_squared_error: 2.0220 - mean_absolute_error: 1.6069 - val_loss: 2.3010 - val_root_mean_squared_error: 2.0206 - val_mean_absolute_error: 1.6056
# Epoch 79/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.4874 - root_mean_squared_error: 2.0174 - mean_absolute_error: 1.6027 - val_loss: 2.2985 - val_root_mean_squared_error: 2.0159 - val_mean_absolute_error: 1.6016
# Epoch 80/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.4466 - root_mean_squared_error: 2.0127 - mean_absolute_error: 1.5986 - val_loss: 2.3022 - val_root_mean_squared_error: 2.0113 - val_mean_absolute_error: 1.5974
# Epoch 81/120
# 364/364 [==============================] - 0s 55us/step - loss: 1.4296 - root_mean_squared_error: 2.0082 - mean_absolute_error: 1.5945 - val_loss: 2.3122 - val_root_mean_squared_error: 2.0067 - val_mean_absolute_error: 1.5933
# Epoch 82/120
# 364/364 [==============================] - 0s 55us/step - loss: 1.3593 - root_mean_squared_error: 2.0034 - mean_absolute_error: 1.5902 - val_loss: 2.3260 - val_root_mean_squared_error: 2.0021 - val_mean_absolute_error: 1.5891
# Epoch 83/120
# 364/364 [==============================] - 0s 58us/step - loss: 1.4879 - root_mean_squared_error: 1.9990 - mean_absolute_error: 1.5863 - val_loss: 2.3429 - val_root_mean_squared_error: 1.9977 - val_mean_absolute_error: 1.5853
# Epoch 84/120
# 364/364 [==============================] - 0s 58us/step - loss: 1.4364 - root_mean_squared_error: 1.9946 - mean_absolute_error: 1.5824 - val_loss: 2.3556 - val_root_mean_squared_error: 1.9934 - val_mean_absolute_error: 1.5814
# Epoch 85/120
# 364/364 [==============================] - 0s 58us/step - loss: 1.4779 - root_mean_squared_error: 1.9904 - mean_absolute_error: 1.5787 - val_loss: 2.3679 - val_root_mean_squared_error: 1.9891 - val_mean_absolute_error: 1.5777
# Epoch 86/120
# 364/364 [==============================] - 0s 63us/step - loss: 1.4516 - root_mean_squared_error: 1.9861 - mean_absolute_error: 1.5749 - val_loss: 2.3776 - val_root_mean_squared_error: 1.9849 - val_mean_absolute_error: 1.5739
# Epoch 87/120
# 364/364 [==============================] - 0s 60us/step - loss: 1.4852 - root_mean_squared_error: 1.9819 - mean_absolute_error: 1.5713 - val_loss: 2.3814 - val_root_mean_squared_error: 1.9807 - val_mean_absolute_error: 1.5704
# Epoch 88/120
# 364/364 [==============================] - 0s 60us/step - loss: 1.4599 - root_mean_squared_error: 1.9778 - mean_absolute_error: 1.5676 - val_loss: 2.3761 - val_root_mean_squared_error: 1.9766 - val_mean_absolute_error: 1.5667
# Epoch 89/120
# 364/364 [==============================] - 0s 77us/step - loss: 1.4601 - root_mean_squared_error: 1.9737 - mean_absolute_error: 1.5639 - val_loss: 2.3791 - val_root_mean_squared_error: 1.9725 - val_mean_absolute_error: 1.5630
# Epoch 90/120
# 364/364 [==============================] - 0s 66us/step - loss: 1.4507 - root_mean_squared_error: 1.9697 - mean_absolute_error: 1.5604 - val_loss: 2.3874 - val_root_mean_squared_error: 1.9685 - val_mean_absolute_error: 1.5595
# Epoch 91/120
# 364/364 [==============================] - 0s 90us/step - loss: 1.4064 - root_mean_squared_error: 1.9656 - mean_absolute_error: 1.5568 - val_loss: 2.3888 - val_root_mean_squared_error: 1.9645 - val_mean_absolute_error: 1.5560
# Epoch 92/120
# 364/364 [==============================] - 0s 63us/step - loss: 1.4786 - root_mean_squared_error: 1.9617 - mean_absolute_error: 1.5534 - val_loss: 2.3848 - val_root_mean_squared_error: 1.9606 - val_mean_absolute_error: 1.5526
# Epoch 93/120
# 364/364 [==============================] - 0s 88us/step - loss: 1.4012 - root_mean_squared_error: 1.9578 - mean_absolute_error: 1.5500 - val_loss: 2.3757 - val_root_mean_squared_error: 1.9566 - val_mean_absolute_error: 1.5491
# Epoch 94/120
# 364/364 [==============================] - 0s 60us/step - loss: 1.4084 - root_mean_squared_error: 1.9539 - mean_absolute_error: 1.5464 - val_loss: 2.3767 - val_root_mean_squared_error: 1.9527 - val_mean_absolute_error: 1.5456
# Epoch 95/120
# 364/364 [==============================] - 0s 60us/step - loss: 1.4677 - root_mean_squared_error: 1.9501 - mean_absolute_error: 1.5432 - val_loss: 2.3761 - val_root_mean_squared_error: 1.9490 - val_mean_absolute_error: 1.5423
# Epoch 96/120
# 364/364 [==============================] - 0s 58us/step - loss: 1.4025 - root_mean_squared_error: 1.9463 - mean_absolute_error: 1.5398 - val_loss: 2.3758 - val_root_mean_squared_error: 1.9452 - val_mean_absolute_error: 1.5389
# Epoch 97/120
# 364/364 [==============================] - 0s 58us/step - loss: 1.3959 - root_mean_squared_error: 1.9425 - mean_absolute_error: 1.5364 - val_loss: 2.3715 - val_root_mean_squared_error: 1.9414 - val_mean_absolute_error: 1.5356
# Epoch 98/120
# 364/364 [==============================] - 0s 55us/step - loss: 1.3367 - root_mean_squared_error: 1.9387 - mean_absolute_error: 1.5330 - val_loss: 2.3689 - val_root_mean_squared_error: 1.9376 - val_mean_absolute_error: 1.5321
# Epoch 99/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.3705 - root_mean_squared_error: 1.9349 - mean_absolute_error: 1.5295 - val_loss: 2.3648 - val_root_mean_squared_error: 1.9339 - val_mean_absolute_error: 1.5287
# Epoch 100/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.2577 - root_mean_squared_error: 1.9311 - mean_absolute_error: 1.5261 - val_loss: 2.3618 - val_root_mean_squared_error: 1.9300 - val_mean_absolute_error: 1.5253
# Epoch 101/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3548 - root_mean_squared_error: 1.9274 - mean_absolute_error: 1.5228 - val_loss: 2.3696 - val_root_mean_squared_error: 1.9264 - val_mean_absolute_error: 1.5220
# Epoch 102/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.3772 - root_mean_squared_error: 1.9238 - mean_absolute_error: 1.5196 - val_loss: 2.3777 - val_root_mean_squared_error: 1.9228 - val_mean_absolute_error: 1.5188
# Epoch 103/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.4853 - root_mean_squared_error: 1.9204 - mean_absolute_error: 1.5167 - val_loss: 2.3904 - val_root_mean_squared_error: 1.9194 - val_mean_absolute_error: 1.5159
# Epoch 104/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.2472 - root_mean_squared_error: 1.9167 - mean_absolute_error: 1.5133 - val_loss: 2.4120 - val_root_mean_squared_error: 1.9157 - val_mean_absolute_error: 1.5126
# Epoch 105/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3488 - root_mean_squared_error: 1.9132 - mean_absolute_error: 1.5102 - val_loss: 2.4253 - val_root_mean_squared_error: 1.9122 - val_mean_absolute_error: 1.5095
# Epoch 106/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.3885 - root_mean_squared_error: 1.9098 - mean_absolute_error: 1.5072 - val_loss: 2.4306 - val_root_mean_squared_error: 1.9089 - val_mean_absolute_error: 1.5065
# Epoch 107/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4026 - root_mean_squared_error: 1.9065 - mean_absolute_error: 1.5043 - val_loss: 2.4316 - val_root_mean_squared_error: 1.9055 - val_mean_absolute_error: 1.5036
# Epoch 108/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3210 - root_mean_squared_error: 1.9030 - mean_absolute_error: 1.5012 - val_loss: 2.4217 - val_root_mean_squared_error: 1.9021 - val_mean_absolute_error: 1.5005
# Epoch 109/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4693 - root_mean_squared_error: 1.8999 - mean_absolute_error: 1.4985 - val_loss: 2.4026 - val_root_mean_squared_error: 1.8989 - val_mean_absolute_error: 1.4979
# Epoch 110/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3687 - root_mean_squared_error: 1.8965 - mean_absolute_error: 1.4957 - val_loss: 2.3824 - val_root_mean_squared_error: 1.8957 - val_mean_absolute_error: 1.4950
# Epoch 111/120
# 364/364 [==============================] - 0s 49us/step - loss: 1.2765 - root_mean_squared_error: 1.8932 - mean_absolute_error: 1.4928 - val_loss: 2.3678 - val_root_mean_squared_error: 1.8923 - val_mean_absolute_error: 1.4921
# Epoch 112/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.4261 - root_mean_squared_error: 1.8900 - mean_absolute_error: 1.4901 - val_loss: 2.3695 - val_root_mean_squared_error: 1.8891 - val_mean_absolute_error: 1.4894
# Epoch 113/120
# 364/364 [==============================] - 0s 52us/step - loss: 1.3076 - root_mean_squared_error: 1.8867 - mean_absolute_error: 1.4872 - val_loss: 2.3845 - val_root_mean_squared_error: 1.8859 - val_mean_absolute_error: 1.4866
# Epoch 114/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3086 - root_mean_squared_error: 1.8836 - mean_absolute_error: 1.4844 - val_loss: 2.4087 - val_root_mean_squared_error: 1.8827 - val_mean_absolute_error: 1.4837
# Epoch 115/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3279 - root_mean_squared_error: 1.8803 - mean_absolute_error: 1.4816 - val_loss: 2.4358 - val_root_mean_squared_error: 1.8795 - val_mean_absolute_error: 1.4810
# Epoch 116/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.2868 - root_mean_squared_error: 1.8772 - mean_absolute_error: 1.4789 - val_loss: 2.4513 - val_root_mean_squared_error: 1.8764 - val_mean_absolute_error: 1.4782
# Epoch 117/120
# 364/364 [==============================] - 0s 44us/step - loss: 1.4026 - root_mean_squared_error: 1.8742 - mean_absolute_error: 1.4762 - val_loss: 2.4458 - val_root_mean_squared_error: 1.8734 - val_mean_absolute_error: 1.4757
# Epoch 118/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.3990 - root_mean_squared_error: 1.8713 - mean_absolute_error: 1.4738 - val_loss: 2.4355 - val_root_mean_squared_error: 1.8704 - val_mean_absolute_error: 1.4732
# Epoch 119/120
# 364/364 [==============================] - 0s 47us/step - loss: 1.2787 - root_mean_squared_error: 1.8682 - mean_absolute_error: 1.4712 - val_loss: 2.4294 - val_root_mean_squared_error: 1.8674 - val_mean_absolute_error: 1.4706
# Epoch 120/120
# 364/364 [==============================] - ETA: 0s - loss: 1.3422 - root_mean_squared_error: 1.8656 - mean_absolute_error: 1.468 - 0s 47us/step - loss: 1.3331 - root_mean_squared_error: 1.8652 - mean_absolute_error: 1.4686 - val_loss: 2.4286 - val_root_mean_squared_error: 1.8644 - val_mean_absolute_error: 1.4680
